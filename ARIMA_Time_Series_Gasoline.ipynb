# %% [markdown]
# <a href="https://colab.research.google.com/github/Long-Live-Lord-Voldemort/Long-Live-Lord-Voldemort/blob/main/ARIMA_Time_Series_Gasoline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install quandl

# %%
import quandl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')

# %%
oil = quandl.get("NSE/OIL", authtoken="vEjGTysiCFBuN-z5bjGP", start_date="1970-01-01", end_date="2022-03-20")

# %%
plt.figure(figsize=(30,7))
plt.plot(oil.Close)
plt.ylabel('$')
plt.xlabel('Date')
plt.show()
